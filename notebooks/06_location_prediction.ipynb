# %% [markdown]
# # 06 Location prediction
# Synthetic targets only; Target_Area is excluded from model inputs.

# %%
from src.case_generator import generate_cases
from src.prediction import train_location_model
cases = generate_cases(anomalies)
model, metrics = train_location_model(cases); metrics['accuracy']
