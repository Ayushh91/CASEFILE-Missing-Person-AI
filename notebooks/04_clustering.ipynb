# %% [markdown]
# # 04 Location clustering
# Area IDs are model states, not official neighborhoods.

# %%
from src.clustering import cluster_locations
clustered, model, centers, metrics = cluster_locations(features)
centers, metrics
