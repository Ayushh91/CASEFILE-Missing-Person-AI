# %% [markdown]
# # 07 Markov route prediction
# Routes are transition probabilities, not confirmed paths.

# %%
from src.route_prediction import build_transition_matrix, predict_route
matrix = build_transition_matrix(anomalies)
predict_route(matrix, cases.iloc[0].Previous_Area)
