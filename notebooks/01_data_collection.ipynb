# %% [markdown]
# # 01 Data collection
# Loads GeoLife if present; otherwise uses labelled fictional demo data.

# %%
from src.data_loader import load_source
data, status = load_source()
print(status, data.shape)
