# %% [markdown]
# # 05 Anomaly detection
# Flags deviations, not suspicious behaviour.

# %%
from src.anomaly_detection import detect_anomalies
anomalies, _, _ = detect_anomalies(clustered)
anomalies.anomaly_label.value_counts()
