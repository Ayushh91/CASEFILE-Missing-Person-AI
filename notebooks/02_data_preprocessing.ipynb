# %% [markdown]
# # 02 Preprocessing
# Validation and removal counts are computed, never invented.

# %%
from src.data_loader import load_source
from src.preprocessing import clean_trajectories
clean, report = clean_trajectories(load_source()[0]); report
