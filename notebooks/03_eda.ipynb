# %% [markdown]
# # 03 EDA and features
# Inspect actual calculated movement distributions.

# %%
from src.feature_engineering import add_movement_features
features = add_movement_features(clean)
features[['distance_km','speed_kmh','hour']].describe()
